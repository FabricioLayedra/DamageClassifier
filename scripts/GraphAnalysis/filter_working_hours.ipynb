# %%
import pandas as pd

# %%
df_eventos = pd.read_csv("output/distancias_20160415.csv")

# %%
df_eventos.tail(5)
# Out:
#          Index FechaEvento  Hora ProvinciaCliente         CantonCliente  \
# 199748  199748  2016-04-15    23       TUNGURAHUA                PATATE
# 199749  199749  2016-04-15    23       TUNGURAHUA                 QUERO
# 199750  199750  2016-04-15    23       TUNGURAHUA  SAN PEDRO DE PELILEO
# 199751  199751  2016-04-15    23       TUNGURAHUA  SAN PEDRO DE PELILEO
# 199752  199752  2016-04-15    23       TUNGURAHUA  SAN PEDRO DE PELILEO
#
#                                   CiudadCliente  \
# 199748                                   PATATE
# 199749  YANAYACU - MOCHAPATA (CAB. EN YANAYACU)
# 199750                 GARCIA MORENO (CHUMAQUI)
# 199751                 GARCIA MORENO (CHUMAQUI)
# 199752                 GARCIA MORENO (CHUMAQUI)
#
#                                ParroquiaCliente  LatitudCliente  \
# 199748                                   PATATE        -1.30875
# 199749  YANAYACU - MOCHAPATA (CAB. EN YANAYACU)        -1.44017
# 199750                 GARCIA MORENO (CHUMAQUI)        -1.32751
# 199751                 GARCIA MORENO (CHUMAQUI)        -1.32001
# 199752                 GARCIA MORENO (CHUMAQUI)        -1.32001
#
#         LongitudCliente  NombreSitioEvento     ...        ParroquiaEvento  \
# 199748         -78.5062    IESS_PORTOVIEJO     ...             PORTOVIEJO
# 199749         -78.6674        CDLA_AURORA     ...                  MANTA
# 199750         -78.5556   PEDERNALES_PLAYA     ...             PEDERNALES
# 199751         -78.5331   EL_CARMEN_MANABI     ...              EL CARMEN
# 199752         -78.5331  SAN_PEDRO_DE_SUMA     ...      SAN PEDRO DE SUMA
#
#        LatitudEvento LongitudEvento       ID  BaseCliente  BaseEvento  \
# 199748     -1.047240       -80.4718  8748980        45226       99990
# 199749     -0.981686       -80.7053   429177        20350       50064
# 199750      0.071642       -80.0548  1662318        20696       21159
# 199751     -0.272244       -79.4577  1179017        39222       16127
# 199752     -0.219281       -79.5417  3999605        39222       17475
#
#         CantidadClientes  GeoIdCliente  GeoIdEvento   Distancia
# 199748                 2           854          489  220.666288
# 199749                 1          1145          418  232.403967
# 199750                 1           910          468  227.558690
# 199751                 1          1317          399  154.964839
# 199752                 1          1317          400  165.581984
#
# [5 rows x 23 columns]

# %%
df_working_hours = df_eventos[(df_eventos["Hora"]>6) & (df_eventos["Hora"]<23)]
df_working_hours = df_working_hours.drop("Index", axis=1)

# %%
df_working_hours.shape
# Out:
# (160440, 22)

# %%
df_working_hours.head(1)
# Out:
#       FechaEvento  Hora ProvinciaCliente          CantonCliente  \
# 32175  2016-04-15     7            AZUAY  CAMILO PONCE ENRIQUEZ
#
#                CiudadCliente       ParroquiaCliente  LatitudCliente  \
# 32175  CAMILO PONCE ENRIQUEZ  CAMILO PONCE ENRIQUEZ        -3.05086
#
#        LongitudCliente NombreSitioEvento ProvinciaEvento     ...      \
# 32175         -79.7285             BAHIA          MANABI     ...
#
#          ParroquiaEvento LatitudEvento LongitudEvento       ID  BaseCliente  \
# 32175  BAHIA DE CARAQUEZ     -0.617236       -80.4367  4111890        41164
#
#        BaseEvento  CantidadClientes  GeoIdCliente  GeoIdEvento   Distancia
# 32175       17507                 1             1          505  280.396885
#
# [1 rows x 22 columns]

# %%
df_working_hours.to_csv("output/working_hours_20160415.csv", index=True)
