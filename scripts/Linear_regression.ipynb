# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm

# %%
def beautify(row):
    row["Afectacion"]

# %%
#merge all data
entropy = pd.read_csv("../utils/entropy.csv", encoding = "ISO-8859-1")
entropy = entropy.rename(columns={"base":"GeoIdEvento"})
entropy = entropy[["GeoIdEvento","diff","zscore"]]
dtw = pd.read_csv("../utils/dtw_tower.csv", encoding = "ISO-8859-1")
dtw = dtw.rename(columns={"GeoId":"GeoIdEvento"})
freq_sub_hours = pd.read_csv("../utils/freq_sub_hours.csv", encoding = "ISO-8859-1")
freq_sub_hours = freq_sub_hours.rename(columns={"GeoId":"GeoIdEvento"})
degree_difference = pd.read_csv("../utils/degree_difference.csv", encoding = "ISO-8859-1")
degree_difference = degree_difference[["GeoIdEvento","InDegreeDifference"]]
etiquetas = pd.read_csv("/home/belen/github/DamageClassifier/utils/manabi-parroquias-shapes/manabi-parroquias-afectacion.csv", encoding = "ISO-8859-1")
etiquetas = etiquetas.rename(columns={"CANTÃ³N":"CANTON", "NOMBRE":"ParroquiaEvento"})
#etiquetas["ParroquiaEvento"]
#etiquetas["ParroquiaEvento"] = etiquetas["ParroquiaEvento"].apply(lambda x: x.title())
etiquetas = etiquetas.replace(np.nan, 'Desconocido', regex=True)
etiquetas["AFECTACION"] = etiquetas["AFECTACION"].apply(lambda x: x.title())
etiquetas = etiquetas[["ParroquiaEvento","AFECTACION"]]
etiquetas["AFECTACION"].value_counts()
# Out:
# Desconocido    46
# Media          19
# Alta            7
# Muy Alta        2
# Name: AFECTACION, dtype: int64

# %%
data_entropy_dtw = pd.merge(entropy,dtw,how="inner",on="GeoIdEvento")
data_with_freqs_hour = pd.merge(data_entropy_dtw, freq_sub_hours, how = "inner", on="GeoIdEvento")
data_with_degree = pd.merge(data_with_freqs_hour, degree_difference, how = "inner", on="GeoIdEvento")

df_eventos = pd.read_csv("../eventos.csv", encoding = "ISO-8859-1")
df_eventos = df_eventos[["GeoIdEvento","ParroquiaEvento"]]
df_eventos = df_eventos.drop_duplicates()
data_with_villages = pd.merge(data_with_degree, df_eventos, how = "inner", on="GeoIdEvento")
data_with_tags = pd.merge(data_with_villages, etiquetas, how = "left", on="ParroquiaEvento")
data_with_tags
# Out:
#      GeoIdEvento      diff    zscore           dtw     0    1    2    3    4  \
# 0            446 -0.000594  0.217008    103.961531     8    4    2    2    3
# 1           1776 -0.011655 -0.716232      1.414214     0    0    0    0    0
# 2            883 -0.000412  0.232427     38.935845     0    5    7    7    2
# 3            377 -0.000563  0.219697   3293.945355  -416 -222 -232 -179 -129
# 4            378 -0.000353  0.237343    160.415087    29   21   11   16   20
# 5            379 -0.000060  0.262076    153.935051    44   42   36   39   39
# 6            380 -0.010776 -0.642017   2851.165025   310  207  199  200  192
# 7            381 -0.000227  0.248035    651.165110    67   29  -17   30   47
# 8            382 -0.000338  0.238640   2347.174898   294  261   24  264  273
# 9            383  0.000000  0.267163    130.782262    29   21    5   26   27
# 10           384 -0.017693 -1.225642    440.961450    43   29   30   32   24
# 11           385 -0.018586 -1.300977    175.288334    18   12   15   13    9
# 12           386 -0.015183 -1.013875    658.039512    92   73   52   53   63
# 13           387 -0.000261  0.245113    810.808239   101   34   19   28   41
# 14           388 -0.000704  0.207799    275.450540    31   18    3   33   38
# 1      0     ...          0     0     1     1     0     0     0
# 2      9     ...         21    23    42    16    14    25     7
# 3   -171     ...       -841  -904  -782  -714  -621  -482  -357
# 4     24     ...         47    33    28    35    40    28    29
# 5     36     ...         66    39    -4    19    21    45    51
# 6    227     ...        699   643   596   654   622   554   493
# 7     52     ...        308   226    87    89   122   117   122
# 8    296     ...       1403   842   365   419   587   598   601
# 9     29     ...         40   -10   -30   -14    45    74    53
# 10    36     ...        121   102    79    56    47    39    29
# 11    15     ...         45    45    43    46    34    38    31
# 12    59     ...        159   143   153   168   157   130   118
# 13    43     ...        241   212   203   170   162   126   105
# 14    53     ...        132    78   112    82   117    84    72
# 15   794     ...       2899  2732  2652  2421  2201  1793  1502
# 16    76     ...        120   108   124   110   103   109    83
# 17   130     ...        403   320   105    62    93   115   137
# 18     2     ...       -437  -431  -392  -353  -283  -169  -148
# 19    88     ...        179   146   175   140   128   106    96
# 20  -159     ...       -195  -227  -211  -180  -170  -148  -109
# 21     9     ...         21    19    22    19    14    12     8
# 22  -154     ...       -370  -396  -469  -439  -440  -412  -315
# 23   223     ...        615   635   491   491   343   309   288
# 24    27     ...         58    60    49    39    37    33    35
# 25   441     ...       1318  1160   940   877   881   801   711
# 26    70     ...        188   192   156   136   157   169   111
# 27     0     ...         41    23    18     6   -24     0     1
# 28    17     ...         75    51    77    50    59    45    36
# 29   -99     ...       -520  -730  -587  -430  -462  -390  -276
# ..   ...     ...        ...   ...   ...   ...   ...   ...   ...
# 109  134     ...        421   466   465   454   401   383   329
# 110  319     ...        717   803   813   817   739   662   594
# 111  377     ...       1404  1399  1336  1192  1089   952   713
# 112  502     ...       1658  1791  1774  1678  1509  1306  1008
# 113  113     ...        743   561   318   255   285   234   229
# 114  115     ...       1492   813    62   145   224   378   359
# 115  606     ...       2783  2481  1999  1975  2017  2127  1981
# 116   50     ...        391   106  -185  -215   -87    50   146
# 117  610     ...       1898  2051  2084  1958  1769  1467  1194
# 118   18     ...        221    32  -110   -67    11    60    98
# 119   60     ...        179   206   206   182   185   140   136
# 120   41     ...        143    90    65    60    33    39    22
# 121  250     ...        976   957   749   689   710   626   434
# 122  -35     ...        -38   -35   -61   -49   -40   -24   -13
# 123 -188     ...       -382  -495  -516  -545  -464  -365  -245
# 124  101     ...        396   265   190   153   204   191   176
# 125   32     ...         56    63    49    21    32    63    57
# 126  401     ...       2030  1786  1417  1150  1163   964   809
# 127   -6     ...        205   201   128   154   147    99   112
# 128   11     ...        125   116    62    51    71    99    63
# 129   12     ...         70    41     9    -1     8     5     5
# 130  154     ...        563   480   268   219   308   304   262
# 131  160     ...        638   463   212   216   260   348   277
# 132  -52     ...        -98  -239  -212  -240  -214  -220  -137
# 133 -378     ...       -950 -1020  -982  -988  -979  -866  -676
# 134 -307     ...       -675  -923  -981  -975  -909  -762  -613
# 135   84     ...        342   335   169   185   112   144   160
# 136  344     ...       1001  1035   870   852   715   607   487
# 137  -40     ...        -93   -97   -76   -69   -82   -55   -41
# 138  -57     ...       -155  -106  -111  -110  -104  -109   -83
#
#      InDegreeDifference                  ParroquiaEvento   AFECTACION
# 0             -8.336893                      SAN LORENZO        Media
# 1             -0.127450                       PORTOVIEJO         Alta
# 2             -2.919991                           CASCOL  Desconocido
# 3            112.122201                       BELLAVISTA  Desconocido
# 4             -2.893696                            NOBOA  Desconocido
# 5             -3.418756                            SUCRE  Desconocido
# 6            -27.671033                          CALCETA        Media
# 7            -19.034317                          CALCETA        Media
# 8            -53.590125                          CALCETA        Media
# 9             -0.501897                        MEMBRILLO  Desconocido
# 10            -9.655106                          QUIROGA  Desconocido
# 11            -3.407384                           BOYACA  Desconocido
# 12            -5.833897                           CANUTO        Media
# 13           -14.652254                           CANUTO        Media
# 14            -3.190072                         CHIBUNGA  Desconocido
# 15          -116.945904                            CHONE        Media
# 16            -6.565696                            CHONE        Media
# 17           -40.635737                            CHONE        Media
# 18           147.946913                         CONVENTO  Desconocido
# 19           -31.874705                      ELOY ALFARO  Desconocido
# 20           112.724222                      ELOY ALFARO  Desconocido
# 21            -3.249226                      ELOY ALFARO  Desconocido
# 22           155.719021                         RICAURTE        Media
# 23           -79.836294                      SAN ANTONIO        Media
# 24           -11.014490                        EL CARMEN  Desconocido
# 25           -30.180939                        EL CARMEN  Desconocido
# 26           -37.032168                SAN PEDRO DE SUMA          NaN
# 27           -25.431097  WILFRIDO LOOR MOREIRA (MAICITO)          NaN
# 28           -19.942205  WILFRIDO LOOR MOREIRA (MAICITO)          NaN
# 29           145.677127                    FLAVIO ALFARO  Desconocido
# ..                  ...                              ...          ...
# 109          -20.103514                       PORTOVIEJO         Alta
# 110          -30.015665                       PORTOVIEJO         Alta
# 111          -58.227298                       PORTOVIEJO         Alta
# 112          -62.638426                       PORTOVIEJO         Alta
# 113          -20.833747                       PORTOVIEJO         Alta
# 114          -53.063806                       PORTOVIEJO         Alta
# 115          -66.225544                       PORTOVIEJO         Alta
# 116          -18.306880                       PORTOVIEJO         Alta
# 117          -68.129560                       PORTOVIEJO         Alta
# 118           -4.535529                       PORTOVIEJO         Alta
# 119           -8.164968                       PORTOVIEJO         Alta
# 120          -12.484618                     PUEBLO NUEVO  Desconocido
# 121          -72.720663             RIOCHICO (RIO CHICO)        Media
# 122           46.351237                      SAN PLACIDO  Desconocido
# 123          146.672029                       MACHALILLA  Desconocido
# 124          -39.869944                     PUERTO LOPEZ  Desconocido
# 125           -8.990617                          SALANGO  Desconocido
# 126         -122.850584                       ROCAFUERTE        Media
# 127          -24.864261                            CANOA         Alta
# 128           75.621052                      SAN VICENTE         Alta
# 129           -1.378104                         AYACUCHO  Desconocido
# 130          -27.219472        SANTA ANA DE VUELTA LARGA  Desconocido
# 131          -41.884636                BAHIA DE CARAQUEZ         Alta
# 132          156.183773                BAHIA DE CARAQUEZ         Alta
# 133          220.365515                        CHARAPOTO        Media
# 134          258.185402                       SAN ISIDRO        Media
# 135          -55.830066                          TOSAGUA        Media
# 136          -90.073041                          TOSAGUA        Media
# 137           49.587167                            MANTA         Alta
# 138           37.560099                            MANTA         Alta
#
# [139 rows x 31 columns]

# %%
X
Y
# Fit and make the predictions by the model
model = sm.OLS(y, X).fit()
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-82-15991256ab2a> in <module>()
# ----> 1 X
#       2 Y
#       3 # Fit and make the predictions by the model
#       4 model = sm.OLS(y, X).fit()
#       5 predictions = model.predict(X)
#
# NameError: name 'X' is not defined
